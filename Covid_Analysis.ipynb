# %% [markdown]
# # EDA

# %% [markdown]
# # Case Study: Covid 19 Data Analysis

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/7b/e5/83fcd7e9db036c179e0352bfcd20f81d728197a16f883e7b90307a88e65e/seaborn-0.13.0-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from seaborn) (1.26.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (6.1.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\captain\anauconda3\envs\py3913\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.6 kB 217.9 kB/s eta 0:00:02
#    ----- --------------------------------- 41.0/294.6 kB 217.9 kB/s eta 0:00:02
#    -------------- ----------------------- 112.6/294.6 kB 504.4 kB/s eta 0:00:01
#    --------------------- ---------------- 163.8/294.6 kB 614.4 kB/s eta 0:00:01
#    ----------------------------- -------- 225.3/294.6 kB 808.4 kB/s eta 0:00:01
#    ----------------------------- -------- 225.3/294.6 kB 808.4 kB/s eta 0:00:01
#    -------------------------------------- 294.6/294.6 kB 758.2 kB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.0

# %%
#Import the Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Import the dataset
dataset = pd.read_csv("covid19_Confirmed_dataset.csv")
dataset.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0     1463     1531     1703     1828     1939     2171
# 1      712      726      736      750      766      773
# 2     3256     3382     3517     3649     3848     4006
# 3      738      738      743      743      743      745
# 4       25       26       27       27       27       27
#
# [5 rows x 104 columns]

# %%
#
dataset.shape
# Out:
# (266, 104)

# %%
#delete the useless columns
df = dataset.drop(["Lat","Long"], axis=1, inplace = True)

# %%
dataset.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0     1463     1531     1703     1828     1939     2171
# 1      712      726      736      750      766      773
# 2     3256     3382     3517     3649     3848     4006
# 3      738      738      743      743      743      745
# 4       25       26       27       27       27       27
#
# [5 rows x 102 columns]

# %%
#aggregate the rows by the country
corona_dataset_aggregated = dataset.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head()
# Out:
#                Province/State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan                 0        0        0        0        0        0
# Albania                     0        0        0        0        0        0
# Algeria                     0        0        0        0        0        0
# Andorra                     0        0        0        0        0        0
# Angola                      0        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...     1092     1176
# Albania               0        0        0        0  ...      609      634
# Algeria               0        0        0        0  ...     2811     2910
# Andorra               0        0        0        0  ...      717      723
# Angola                0        0        0        0  ...       24       25
#
#                 4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  \
# Country/Region
# Afghanistan        1279     1351     1463     1531     1703     1828     1939
# Albania             663      678      712      726      736      750      766
# Algeria            3007     3127     3256     3382     3517     3649     3848
# Andorra             723      731      738      738      743      743      743
# Angola               25       25       25       26       27       27       27
#
#                 4/30/20
# Country/Region
# Afghanistan        2171
# Albania             773
# Algeria            4006
# Andorra             745
# Angola               27
#
# [5 rows x 101 columns]

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 101)

# %%
#Visualise data related to a country
corona_dataset_aggregated.loc["India"].plot()
corona_dataset_aggregated.loc["Afghanistan"].plot()
corona_dataset_aggregated.loc["Spain"].plot()
#corona_dataset_aggregated.loc["China"].plot()
plt.legend()

# %%
#Calculate a good measure
corona_dataset_aggregated.loc["Spain"].plot()
# Out:
# <Axes: >

# %%
corona_dataset_aggregated.loc["Spain"][:3].plot()
# Out:
# <Axes: >

# %%
#Calculate the first derivate of the curve
corona_dataset_aggregated.loc["Spain"].diff().plot()
# Out:
# <Axes: >

# %%
#Maximum infection rate
corona_dataset_aggregated.loc["Spain"].diff().max()
# Out:
# 9630

# %%
corona_dataset_aggregated.loc["India"].diff().max()
# Out:
# 1893

# %%
"""countries = list(corona_dataset_aggregated.index)
max_infection_rates = []

for c in countries:
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
corona_dataset_aggregated["Max_infection_rates"]= max_infection_rates"""
# Out:
# 'countries = list(corona_dataset_aggregated.index)\nmax_infection_rates = []\n\nfor c in countries:\n    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())\ncorona_dataset_aggregated["Max_infection_rates"]= max_infection_rates'

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []

for c in countries:
    # Convert the column to numeric and handle missing values
    diff_values = pd.to_numeric(corona_dataset_aggregated.loc[c], errors='coerce').diff().fillna(0)
    
    # Append the maximum infection rate to the list
    max_infection_rates.append(diff_values.max())

# Add the new column to the DataFrame
corona_dataset_aggregated["Max_infection_rates"] = max_infection_rates

# %%
corona_dataset_aggregated
# Out:
#                    Province/State  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan                     0        0        0        0        0
# Albania                         0        0        0        0        0
# Algeria                         0        0        0        0        0
# Andorra                         0        0        0        0        0
# Angola                          0        0        0        0        0
# ...                           ...      ...      ...      ...      ...
# West Bank and Gaza              0        0        0        0        0
# Western Sahara                  0        0        0        0        0
# Yemen                           0        0        0        0        0
# Zambia                          0        0        0        0        0
# Zimbabwe                        0        0        0        0        0
#
#                     1/26/20  1/27/20  1/28/20  1/29/20  1/30/20  ...  4/22/20  \
# Country/Region                                                   ...
# Afghanistan               0        0        0        0        0  ...     1176
# Albania                   0        0        0        0        0  ...      634
# Algeria                   0        0        0        0        0  ...     2910
# Andorra                   0        0        0        0        0  ...      723
# Angola                    0        0        0        0        0  ...       25
# ...                     ...      ...      ...      ...      ...  ...      ...
# West Bank and Gaza        0        0        0        0        0  ...      474
# Western Sahara            0        0        0        0        0  ...        6
# Yemen                     0        0        0        0        0  ...        1
# Zambia                    0        0        0        0        0  ...       74
# Zimbabwe                  0        0        0        0        0  ...       28
#
#                     4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  \
# Country/Region
# Afghanistan            1279     1351     1463     1531     1703     1828
# Albania                 663      678      712      726      736      750
# Algeria                3007     3127     3256     3382     3517     3649
# Andorra                 723      731      738      738      743      743
# Angola                   25       25       25       26       27       27
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza      480      484      342      342      342      343
# Western Sahara            6        6        6        6        6        6
# Yemen                     1        1        1        1        1        1
# Zambia                   76       84       84       88       88       95
# Zimbabwe                 28       29       31       31       32       32
#
#                     4/29/20  4/30/20  Max_infection_rates
# Country/Region
# Afghanistan            1939     2171                232.0
# Albania                 766      773                 34.0
# Algeria                3848     4006                199.0
# Andorra                 743      745                 43.0
# Angola                   27       27                  5.0
# ...                     ...      ...                  ...
# West Bank and Gaza      344      344                 66.0
# Western Sahara            6        6                  4.0
# Yemen                     6        6                  5.0
# Zambia                   97      106                  9.0
# Zimbabwe                 32       40                  8.0
#
# [187 rows x 102 columns]

# %%
#Create a new dataframe
corona_data = pd.DataFrame(corona_dataset_aggregated["Max_infection_rates"])

# %%
corona_data
# Out:
#                     Max_infection_rates
# Country/Region
# Afghanistan                       232.0
# Albania                            34.0
# Algeria                           199.0
# Andorra                            43.0
# Angola                              5.0
# ...                                 ...
# West Bank and Gaza                 66.0
# Western Sahara                      4.0
# Yemen                               5.0
# Zambia                              9.0
# Zimbabwe                            8.0
#
# [187 rows x 1 columns]

# %%
#Importing the dataset 2
happiness_report = pd.read_csv("worldwide_happiness_report.csv")

# %%
happiness_report
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# 1             1.573                    0.996                         0.592
# 2             1.582                    1.028                         0.603
# 3             1.624                    1.026                         0.591
# 4             1.522                    0.999                         0.557
# ..              ...                      ...                           ...
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 0         0.153                      0.393
# 1         0.252                      0.410
# 2         0.271                      0.341
# 3         0.354                      0.118
# 4         0.322                      0.298
# ..          ...                        ...
# 151       0.217                      0.411
# 152       0.276                      0.147
# 153       0.158                      0.025
# 154       0.235                      0.035
# 155       0.202                      0.091
#
# [156 rows x 9 columns]

# %%
#drop the useless columns
useless_cols = ["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
happiness_report.drop(useless_cols, axis=1, inplace= True)

# %%
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report.set_index("Country or region", inplace = True)
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
#Join the two dataset we have created
corona_data.shape
# Out:
# (187, 1)

# %%
happiness_report.shape
# Out:
# (156, 4)

# %%
data = corona_data.join(happiness_report, how = "inner")
data
# Out:
#              Max_infection_rates  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
# ...                          ...             ...             ...
# Venezuela                   29.0           0.960           1.427
# Vietnam                     19.0           0.741           1.346
# Yemen                        5.0           0.287           1.163
# Zambia                       9.0           0.578           1.058
# Zimbabwe                     8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283
# ...                              ...                           ...
# Venezuela                      0.805                         0.154
# Vietnam                        0.851                         0.543
# Yemen                          0.463                         0.143
# Zambia                         0.426                         0.431
# Zimbabwe                       0.433                         0.361
#
# [143 rows x 5 columns]

# %%
data.corr()
# Out:
#                               Max_infection_rates  GDP per capita  \
# Max_infection_rates                      1.000000        0.250118
# GDP per capita                           0.250118        1.000000
# Social support                           0.191958        0.759468
# Healthy life expectancy                  0.289263        0.863062
# Freedom to make life choices             0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# Max_infection_rates                 0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# Max_infection_rates                               0.078196
# GDP per capita                                    0.394603
# Social support                                    0.456246
# Healthy life expectancy                           0.427892
# Freedom to make life choices                      1.000000

# %%
data
# Out:
#              Max_infection_rates  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
# ...                          ...             ...             ...
# Venezuela                   29.0           0.960           1.427
# Vietnam                     19.0           0.741           1.346
# Yemen                        5.0           0.287           1.163
# Zambia                       9.0           0.578           1.058
# Zimbabwe                     8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283
# ...                              ...                           ...
# Venezuela                      0.805                         0.154
# Vietnam                        0.851                         0.543
# Yemen                          0.463                         0.143
# Zambia                         0.426                         0.431
# Zimbabwe                       0.433                         0.361
#
# [143 rows x 5 columns]

# %%
#Visualization
#x = data["GDP per capita"]
#y = data["Max_infection_rates"]
#sns.scatterplot(x=x,y=y)
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_rates'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming data is your DataFrame
x = data["GDP per capita"]
y = data["Max_infection_rates"]

# Use sns.scatterplot with x and y arguments
sns.scatterplot(x=x, y=np.log(y))

# Add labels and title if needed
plt.xlabel("GDP per capita")
plt.ylabel("Max Infection Rates")
plt.title("Scatter Plot of GDP per capita vs. Max Infection Rates")

# Show the plot
plt.show()

# %%
#Plot Regression Model for this
sns.regplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_rates'>

# %%
x = data["Social support"]
y = data["Max_infection_rates"]
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='Max_infection_rates'>

# %%
sns.regplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='Max_infection_rates'>

# %%
x =data["Healthy life expectancy"]
y =data["Max_infection_rates"]
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Max_infection_rates'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Max_infection_rates'>

# %%
x = data["Freedom to make life choices"]
y = data["Max_infection_rates"]
sns.scatterplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infection_rates'>

# %%
sns.regplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infection_rates'>
